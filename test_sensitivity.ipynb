# %%
from config import Config
from dgp import DGP

cfg = Config(p=10)
dgp = DGP(config=cfg, signal_type="strong", error_type="gaussian")
data = dgp.generate()

X, y, beta, support, snr = data["X"], data["y"], data["beta"], data["support"], data["snr"]

print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")
print(f"beta shape: {beta.shape}")
print(f"SNR: {snr}")
print(f"Support: {support}")
# Out:
# X shape: (250, 10)
# y shape: (250,)
# beta shape: (10,)
# SNR: 182.68108054649556
# Support: [0, 1, 2, 3, 4]
